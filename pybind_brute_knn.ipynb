# %%
from src import pybind_brute_knn
import numpy as np 

points = np.random.rand(60000, 128) * 1000

# %%
nn = pybind_brute_knn.EuclideanKnn(points)

# %%
# %%time
nn.kneighbors(points[10], 10)
# Out:
# CPU times: total: 2.88 s
# Wall time: 10.1 s
# [[43.74246858273623,
#   136.5072509014077,
#   572.8377201223642,
#   384.7772896417344,
#   488.55797497718055,
#   350.9852388223278,
#   187.97473771206685,
#   998.2520417368411,
#   904.9503906329704,
#   419.2490454561801,
#   236.93144422639156,
#   241.7253906810669,
#   827.183831279346,
#   233.60278259514254,
#   911.1452391119343,
#   923.0960861575826,
#   694.3587788003333,
#   320.68721753709127,
#   394.04622488961616,
#   604.8306636010105,
#   736.4130671242197,
#   278.18689995122946,
#   553.361564672409,
#   195.78605010172612,
#   82.66861116222857,
#   410.627937569662,
#   769.8824226339344,
#   773.8860489029972,
#   77.88419957136594,
#   397.6865952248675,
#   186.92859640041524,
#   108.39276415561261,
#   719.5329056442641,
#   216.12662746016176,
#   142.74156465313737,
#   580.7031033537518,
#   881.7061618267754,
#   226.1293125295253,
#   398.4873489377826,
#   419.5635544103198,
#   728.7659527284518,
# ...
